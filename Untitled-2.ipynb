# %% [markdown]
# # Coût de douane import= SOMMES:
# VD+DD+DA+TVA+CAC+PCT+DAO+RI+TCI+CIA+PRELEVEMENT OHADA+PRD+ TAXE PHYTOSANITAIRE
#
# - Détermination de la valeur en douane (VD) (Transports +manutention+coût de la marchandise)
# - Droit de douane (DD) (5,10,20,30% selon l'espèce tarifaire d'appartenance)
# - Droit d'accise (DA) (Sur les produits de luxe 25%, les alcools et le tabac 25%, les voitures 12,5% à appliquer sur (VD+DD)
# - TVA 17,5% à appliquer sur VD+DD+DA
# - Centimes additionnels communaux (CAC) 10% de la TVA
# - Redevance informatique (RI) 0,45% (de VD ou de valeur CAF)
# - Taxe communautaire d'intégration TCI 0,6% de VD ou de valeur CAF
# - Contribution pour l'intégration 0,4% de VD ou de CAF
# - Prélèvement OHADA (PRO) 0,05% VD ou CAF
# - Précompte sur achat 1% de VD, si l'opérateur n'a pas de NIU 5% de VD
# - Frais de facilitation GUCE 12500frs/dossier validé
# - Taxe phytosanitaire 50frs/tonne
# - TEL 10 000frs

# %% [markdown]
# ---
#
# ## 1. **Qu'est-ce que l'espèce tarifaire dans la zone CEMAC ?**
#
# Dans la **zone CEMAC** (Communauté Économique et Monétaire de l'Afrique Centrale : Cameroun, Centrafrique, Congo, Gabon, Guinée Équatoriale, Tchad), **l'espèce tarifaire** désigne **la classification des marchandises importées selon leur nature** afin d'appliquer le taux de droit de douane correspondant.
#
# Chaque bien est classé dans une catégorie précise avec un taux de droit de douane spécifique :
#
# | Catégorie de biens | Exemples | Taux de droit de douane (DD) |
# |:-------------------|:---------|:----------------------------|
# | **Biens de première nécessité** | Riz, médicaments de base, lait, etc. | **5%** |
# | **Matières premières** | Bois brut, minerai, coton non filé, etc. | **10%** |
# | **Biens intermédiaires et divers** | Pièces détachées, semi-produits industriels | **20%** |
# | **Biens de consommation courante** | Voitures, vêtements, appareils électroniques | **30%** |
#
# ---
#
# ## 2. **Comment se calcule le coût total de douane à l'importation ?**
#
# Le **coût de douane import** est la **somme** de plusieurs éléments, pas seulement le droit de douane !
#
# La formule indicative est :
#
# ```text
# Coût de douane import = VD + DD + DA + TVA + CAC + PCT + DAO + RI + TCI + CIA + PRO + PRD + Taxe Phytosanitaire
# ```
#
# **Explication de chaque élément** :
#
# | Élément | Définition | Taux/Calcul |
# |:--------|:-----------|:------------|
# | **VD (Valeur en douane)** | Coût de la marchandise + frais de transport + manutention | Montant de base |
# | **DD (Droit de douane)** | Selon l'espèce tarifaire | 5%, 10%, 20% ou 30% de VD |
# | **DA (Droit d'accise)** | Sur produits de luxe, alcool, tabac, voitures | 25% ou 12,5% sur (VD + DD) |
# | **TVA** | Taxe sur la valeur ajoutée | 17,5% sur (VD + DD + DA) |
# | **CAC** | Centimes additionnels communaux | 10% de la TVA |
# | **RI** | Redevance informatique | 0,45% de VD |
# | **TCI** | Taxe communautaire d'intégration | 0,6% de VD |
# | **CIA** | Contribution pour l'intégration africaine | 0,4% de VD |
# | **PRO** | Prélèvement OHADA | 0,05% de VD |
# | **PRD** | Précompte sur achat | 1% de VD si NIU, 5% si pas de NIU |
# | **DAO** | Droit d'entrée additionnel | S'applique dans certains cas spécifiques |
# | **GUCE** | Frais de facilitation GUCE | 12 500 FCFA par dossier |
# | **Taxe phytosanitaire** | Pour les produits végétaux | 50 FCFA/tonne |
# | **TEL** | Autre taxe liée au traitement électronique | 10 000 FCFA |
#
# ---
#
# ### 3. **Détail étape par étape du calcul**
#
# ✅ **1. Déterminer la VD** :
# *(prix FOB + fret + assurance + manutention)*
#
# ✅ **2. Appliquer le droit de douane (DD)** :
# *(VD × % selon catégorie)*
#
# ✅ **3. Calculer le droit d'accise (DA)** :
# *(25% ou 12,5% sur VD + DD si concerné)*
#
# ✅ **4. Appliquer la TVA** :
# *(17,5% de (VD + DD + DA))*
#
# ✅ **5. Ajouter les autres frais** :
# - CAC = 10% de TVA
# - RI = 0,45% de VD
# - TCI = 0,6% de VD
# - CIA = 0,4% de VD
# - PRO = 0,05% de VD
# - PRD = 1% ou 5% de VD
# - GUCE = 12 500 FCFA
# - Phytosanitaire = 50 FCFA par tonne
# - TEL = 10 000 FCFA
#
# ---
#
# ## 🛠 Exemple simplifié :
#
# Supposons tu importes **des biens de consommation courante** (donc **30%**) pour une **valeur de douane de 1 000 000 FCFA**.
#
# | Éléments | Calcul | Montant (FCFA) |
# |:---------|:-------|:--------------|
# | VD | - | 1 000 000 |
# | DD | 30% de VD | 300 000 |
# | DA | (Supposons aucun DA) | 0 |
# | TVA | 17,5% de (VD+DD) = 17,5% de 1 300 000 | 227 500 |
# | CAC | 10% de TVA = 10% de 227 500 | 22 750 |
# | RI | 0,45% de VD = 0,45% de 1 000 000 | 4 500 |
# | TCI | 0,6% de VD | 6 000 |
# | CIA | 0,4% de VD | 4 000 |
# | PRO | 0,05% de VD | 500 |
# | PRD | 1% de VD (si NIU) | 10 000 |
# | GUCE | - | 12 500 |
# | Phytosanitaire (ex. 1 tonne) | - | 50 |
# | TEL | - | 10 000 |
# | **Total** | **SOMME** | **1 597 800 FCFA** |
#
# ---

# %% [markdown]
# 📦 Catégories de biens et exemples de produits en CEMAC
# 1. Biens de première nécessité (Taux : 5%)
# ➡️ Ce sont des produits essentiels pour la population.
#
# Exemples :
#
# Riz
#
# Blé
#
# Maïs
#
# Lait (en poudre, concentré ou liquide non sucré)
#
# Médicaments
#
# Produits pharmaceutiques essentiels
#
# Engrais
#
# Intrants agricoles (semences, pesticides)
#
# Matériel médical
#
# Matériel didactique (livres scolaires, fournitures scolaires)
#
# Eau potable
#
# Électricité (importée)
#
# Farine de blé
#
# 2. Matières premières (Taux : 10%)
# ➡️ Destinées à la transformation industrielle ou artisanale.
#
# Exemples :
#
# Coton brut
#
# Bois brut
#
# Cuir brut
#
# Peaux fraîches
#
# Minerais (fer, bauxite, cuivre, etc.)
#
# Hydrocarbures non raffinés
#
# Huiles végétales brutes
#
# Sucre brut
#
# Graines de cacao, café non torréfié
#
# Latex naturel
#
# Produits chimiques de base pour l'industrie
#
# 3. Biens intermédiaires et divers (Taux : 20%)
# ➡️ Utilisés dans le processus de production ou produits semi-finis.
#
# Exemples :
#
# Fils, tissus, textiles semi-finis
#
# Huiles raffinées
#
# Produits chimiques finis
#
# Matériel de construction (ciment, fer à béton, carreaux)
#
# Papier, carton
#
# Pièces détachées automobiles
#
# Appareils électroménagers semi-finis
#
# Semi-conducteurs
#
# Outillage industriel
#
# Articles de quincaillerie
#
# Produits plastiques semi-finis (granulés, films)
#
# 4. Biens de consommation courante (Taux : 30%)
# ➡️ Produits finis destinés à la consommation directe.
#
# Exemples :
#
# Voitures particulières
#
# Motos
#
# Vêtements et chaussures
#
# Équipements électroménagers (réfrigérateurs, téléviseurs)
#
# Produits alimentaires transformés (biscuits, boissons gazeuses, jus)
#
# Produits cosmétiques et de beauté
#
# Meubles
#
# Articles électroniques (smartphones, tablettes, ordinateurs)
#
# Bijoux
#
# Parfums
#
# Spiritueux, vins
#
# Cigarettes et tabacs manufacturés

# %%
print('hiv')
# Out:
# hiv
